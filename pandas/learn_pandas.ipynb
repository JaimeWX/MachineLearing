# %%
import pandas as pd

# Reading a csv into Pandas.
df = pd.read_csv('uk_rain_2014.csv', header=0)

# %%
# Getting first x rows.
df.head(5)
# Out:
#   Water Year  Rain (mm) Oct-Sep  Outflow (m3/s) Oct-Sep  Rain (mm) Dec-Feb  \
# 0    1980/81               1182                    5408                292
# 1    1981/82               1098                    5112                257
# 2    1982/83               1156                    5701                330
# 3    1983/84                993                    4265                391
# 4    1984/85               1182                    5364                217
#
#    Outflow (m3/s) Dec-Feb  Rain (mm) Jun-Aug  Outflow (m3/s) Jun-Aug
# 0                    7248                174                    2212
# 1                    7316                242                    1936
# 2                    8567                124                    1802
# 3                    8905                141                    1078
# 4                    5813                343                    4313

# %%
# Getting last x rows.
df.tail(5)
# Out:
#    Water Year  Rain (mm) Oct-Sep  Outflow (m3/s) Oct-Sep  Rain (mm) Dec-Feb  \
# 28    2008/09               1139                    4941                268
# 29    2009/10               1103                    4738                255
# 30    2010/11               1053                    4521                265
# 31    2011/12               1285                    5500                339
# 32    2012/13               1090                    5329                350
#
#     Outflow (m3/s) Dec-Feb  Rain (mm) Jun-Aug  Outflow (m3/s) Jun-Aug
# 28                    6690                323                    3189
# 29                    6435                244                    1958
# 30                    6593                267                    2885
# 31                    7630                379                    5261
# 32                    9615                187                    1797

# %%
# Changing column lable
df.columns = ['water_year','rain_octsep','outflow_octsep','rain_decfeb','outflow_decfeb','rain_junaug','outflow_junaug']
df.head(5)
# Out:
#   water_year  rain_octsep  outflow_octsep  rain_decfeb  outflow_decfeb  \
# 0    1980/81         1182            5408          292            7248
# 1    1981/82         1098            5112          257            7316
# 2    1982/83         1156            5701          330            8567
# 3    1983/84          993            4265          391            8905
# 4    1984/85         1182            5364          217            5813
#
#    rain_junaug  outflow_junaug
# 0          174            2212
# 1          242            1936
# 2          124            1802
# 3          141            1078
# 4          343            4313

# %%
# Finding out how many rows dataset has.
len(df)
# Out:
# 33

# %%
# Finding out basic statistical information on your dataset. 
# std: Standard deviation
pd.options.display.float_format = '{:,.3f}'.format
# Limit output to 3 decimal places.
df.describe()
# Out:
#        rain_octsep  outflow_octsep  rain_decfeb  outflow_decfeb  rain_junaug  \
# count       33.000          33.000       33.000          33.000       33.000
# mean     1,129.000       5,019.182      325.364       7,926.545      237.485
# std        101.900         658.588       69.995       1,692.800       66.168
# min        856.000       3,479.000      206.000       4,578.000      103.000
# 25%      1,053.000       4,506.000      268.000       6,690.000      193.000
# 50%      1,139.000       5,112.000      309.000       7,630.000      229.000
# 75%      1,182.000       5,497.000      360.000       8,905.000      280.000
# max      1,387.000       6,391.000      484.000      11,486.000      379.000
#
#        outflow_junaug
# count          33.000
# mean        2,439.758
# std         1,025.914
# min         1,078.000
# 25%         1,797.000
# 50%         2,142.000
# 75%         2,959.000
# max         5,261.000

# %%
# Getting a column by label
df['rain_octsep']
# Out:
# 0     1182
# 1     1098
# 2     1156
# 3      993
# 4     1182
# 5     1027
# 6     1151
# 7     1210
# 8      976
# 9     1130
# 10    1022
# 11    1151
# 12    1130
# 13    1162
# 14    1110
# 15     856
# 16    1047
# 17    1169
# 18    1268
# 19    1204
# 20    1239
# 21    1185
# 22    1021
# 23    1165
# 24    1095
# 25    1046
# 26    1387
# 27    1225
# 28    1139
# 29    1103
# 30    1053
# 31    1285
# 32    1090
# Name: rain_octsep, dtype: int64

# %%
# Getting a column by label using .
df.rain_octsep
# Out:
# 0     1182
# 1     1098
# 2     1156
# 3      993
# 4     1182
# 5     1027
# 6     1151
# 7     1210
# 8      976
# 9     1130
# 10    1022
# 11    1151
# 12    1130
# 13    1162
# 14    1110
# 15     856
# 16    1047
# 17    1169
# 18    1268
# 19    1204
# 20    1239
# 21    1185
# 22    1021
# 23    1165
# 24    1095
# 25    1046
# 26    1387
# 27    1225
# 28    1139
# 29    1103
# 30    1053
# 31    1285
# 32    1090
# Name: rain_octsep, dtype: int64

# %%
# Creating a series of booleans based on a condtional
df.rain_octsep < 1000 # Or df['rain_octsep'] < 1000
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# Name: rain_octsep, dtype: bool

# %%
# Filtering by multiple conditionals
df[(df.rain_octsep < 1000) & (df.outflow_octsep < 4000)]
# Can't use the keyword 'and'!!!
# Out:
#    water_year  rain_octsep  outflow_octsep  rain_decfeb  outflow_decfeb  \
# 15    1995/96          856            3479          245            5515
#
#     rain_junaug  outflow_junaug
# 15          172            1439

# %%
# Filtering by string methods
df[df.water_year.str.startswith('199')]
# Out:
#    water_year  rain_octsep  outflow_octsep  rain_decfeb  outflow_decfeb  \
# 10    1990/91         1022            4418          305            7120
# 11    1991/92         1151            4506          246            5493
# 12    1992/93         1130            5246          308            8751
# 13    1993/94         1162            5583          422           10109
# 14    1994/95         1110            5370          484           11486
# 15    1995/96          856            3479          245            5515
# 16    1996/97         1047            4019          258            5770
# 17    1997/98         1169            4953          341            7747
# 18    1998/99         1268            5824          360            8771
# 19    1999/00         1204            5665          417           10021
#
#     rain_junaug  outflow_junaug
# 10          216            1923
# 11          280            2118
# 12          219            2551
# 13          193            1638
# 14          103            1231
# 15          172            1439
# 16          256            2102
# 17          285            3206
# 18          225            2240
# 19          197            2166

# %%
# Getting a row via a numerical index
# iloc 只对数字型的标签有用。
df.iloc[30]
# Out:
# water_year        2010/11
# rain_octsep          1053
# outflow_octsep       4521
# rain_decfeb           265
# outflow_decfeb       6593
# rain_junaug           267
# outflow_junaug       2885
# Name: 30, dtype: object

# %%
# Setting a new index from an existing column
df = df.set_index(['water_year'])
df.head(5)
# Out:
#             rain_octsep  outflow_octsep  rain_decfeb  outflow_decfeb  \
# water_year
# 1980/81            1182            5408          292            7248
# 1981/82            1098            5112          257            7316
# 1982/83            1156            5701          330            8567
# 1983/84             993            4265          391            8905
# 1984/85            1182            5364          217            5813
#
#             rain_junaug  outflow_junaug
# water_year
# 1980/81             174            2212
# 1981/82             242            1936
# 1982/83             124            1802
# 1983/84             141            1078
# 1984/85             343            4313

# %%
# Getting a row via a label-based index
df.loc['2000/01']
# Out:
# rain_octsep       1239
# outflow_octsep    6092
# rain_decfeb        328
# outflow_decfeb    9347
# rain_junaug        236
# outflow_junaug    2142
# Name: 2000/01, dtype: int64

# %%
df.sort_index(ascending=False).head(5) #inplace = True to apple the sorting in place
# Out:
#             rain_octsep  outflow_octsep  rain_decfeb  outflow_decfeb  \
# water_year
# 2012/13            1090            5329          350            9615
# 2011/12            1285            5500          339            7630
# 2010/11            1053            4521          265            6593
# 2009/10            1103            4738          255            6435
# 2008/09            1139            4941          268            6690
#
#             rain_junaug  outflow_junaug
# water_year
# 2012/13             187            1797
# 2011/12             379            5261
# 2010/11             267            2885
# 2009/10             244            1958
# 2008/09             323            3189

# %%
df
# Out:
#             rain_octsep  outflow_octsep  rain_decfeb  outflow_decfeb  \
# water_year
# 1980/81            1182            5408          292            7248
# 1981/82            1098            5112          257            7316
# 1982/83            1156            5701          330            8567
# 1983/84             993            4265          391            8905
# 1984/85            1182            5364          217            5813
# 1985/86            1027            4991          304            7951
# 1986/87            1151            5196          295            7593
# 1987/88            1210            5572          343            8456
# 1988/89             976            4330          309            6465
# 1989/90            1130            4973          470           10520
# 1990/91            1022            4418          305            7120
# 1991/92            1151            4506          246            5493
# 1992/93            1130            5246          308            8751
# 1993/94            1162            5583          422           10109
# 1994/95            1110            5370          484           11486
# 1995/96             856            3479          245            5515
# 1996/97            1047            4019          258            5770
# 1997/98            1169            4953          341            7747
# 1998/99            1268            5824          360            8771
# 1999/00            1204            5665          417           10021
# 2000/01            1239            6092          328            9347
# 2001/02            1185            5402          380            8891
# 2002/03            1021            4366          272            7093
# 2003/04            1165            4275          348            7493
# 2004/05            1095            4547          309            7183
# 2005/06            1046            4059          206            4578
# 2006/07            1387            6391          437           10926
# 2007/08            1225            5497          386            9485
# 2008/09            1139            4941          268            6690
# 2009/10            1103            4738          255            6435
# 2010/11            1053            4521          265            6593
# 2011/12            1285            5500          339            7630
# 2012/13            1090            5329          350            9615
#
#             rain_junaug  outflow_junaug
# water_year
# 1980/81             174            2212
# 1981/82             242            1936
# 1982/83             124            1802
# 1983/84             141            1078
# 1984/85             343            4313
# 1985/86             229            2595
# 1986/87             267            2826
# 1987/88             294            3154
# 1988/89             200            1440
# 1989/90             209            1740
# 1990/91             216            1923
# 1991/92             280            2118
# 1992/93             219            2551
# 1993/94             193            1638
# 1994/95             103            1231
# 1995/96             172            1439
# 1996/97             256            2102
# 1997/98             285            3206
# 1998/99             225            2240
# 1999/00             197            2166
# 2000/01             236            2142
# 2001/02             259            3187
# 2002/03             176            1478
# 2003/04             315            2959
# 2004/05             217            1799
# 2005/06             188            1474
# 2006/07             357            5168
# 2007/08             320            3505
# 2008/09             323            3189
# 2009/10             244            1958
# 2010/11             267            2885
# 2011/12             379            5261
# 2012/13             187            1797

# %%
# Returning an index to data
df = df.reset_index('water_year')
df.head(5)
# Out:
#   water_year  rain_octsep  outflow_octsep  rain_decfeb  outflow_decfeb  \
# 0    1980/81         1182            5408          292            7248
# 1    1981/82         1098            5112          257            7316
# 2    1982/83         1156            5701          330            8567
# 3    1983/84          993            4265          391            8905
# 4    1984/85         1182            5364          217            5813
#
#    rain_junaug  outflow_junaug
# 0          174            2212
# 1          242            1936
# 2          124            1802
# 3          141            1078
# 4          343            4313

# %%
# Applying a function to a column
def base_year(year):
    base_year = year[:4]
    base_year= pd.to_datetime(base_year).year
    return base_year

df['year'] = df.water_year.apply(base_year)
df.head(5)
# Out:
#   water_year  rain_octsep  outflow_octsep  rain_decfeb  outflow_decfeb  \
# 0    1980/81         1182            5408          292            7248
# 1    1981/82         1098            5112          257            7316
# 2    1982/83         1156            5701          330            8567
# 3    1983/84          993            4265          391            8905
# 4    1984/85         1182            5364          217            5813
#
#    rain_junaug  outflow_junaug  year
# 0          174            2212  1980
# 1          242            1936  1981
# 2          124            1802  1982
# 3          141            1078  1983
# 4          343            4313  1984

# %%
#Manipulating structure (groupby, unstack, pivot)
# Grouby
# 得到每一个10年的最大值
df.groupby(df.year // 10 *10).max()
# Out:
#      water_year  rain_octsep  outflow_octsep  rain_decfeb  outflow_decfeb  \
# year
# 1980    1989/90         1210            5701          470           10520
# 1990    1999/00         1268            5824          484           11486
# 2000    2009/10         1387            6391          437           10926
# 2010    2012/13         1285            5500          350            9615
#
#       rain_junaug  outflow_junaug  year
# year
# 1980          343            4313  1989
# 1990          285            3206  1999
# 2000          357            5168  2009
# 2010          379            5261  2012

# %%
# Grouping by multiple columns
decade_rain = df.groupby([df.year // 10 * 10, df.rain_octsep // 1000 * 1000])[['outflow_octsep','outflow_decfeb', 'outflow_junaug']].mean()
decade_rain
# 第一行的第三列表示1980-1989年rain_octsep在0-1000范围内outflow_octsep的平均值
# 第一行的第三列表示1980-1989年rain_octsep > 1000 时，outflow_octsep的平均值
# Out:
#                   outflow_octsep  outflow_decfeb  outflow_junaug
# year rain_octsep
# 1980 0                 4,297.500       7,685.000       1,259.000
#      1000              5,289.625       7,933.000       2,572.250
# 1990 0                 3,479.000       5,515.000       1,439.000
#      1000              5,064.889       8,363.111       2,130.556
# 2000 1000              5,030.800       7,812.100       2,685.900
# 2010 1000              5,116.667       7,946.000       3,314.333

# %%
# Unstacking
# 将一列数据设置为列标签
decade_rain.unstack(0)
# Out:
#             outflow_octsep                               outflow_decfeb  \
# year                  1980      1990      2000      2010           1980
# rain_octsep
# 0                4,297.500 3,479.000       nan       nan      7,685.000
# 1000             5,289.625 5,064.889 5,030.800 5,116.667      7,933.000
#
#                                           outflow_junaug                      \
# year             1990      2000      2010           1980      1990      2000
# rain_octsep
# 0           5,515.000       nan       nan      1,259.000 1,439.000       nan
# 1000        8,363.111 7,812.100 7,946.000      2,572.250 2,130.556 2,685.900
#
#
# year             2010
# rain_octsep
# 0                 nan
# 1000        3,314.333

# %%
# More unstacking
decade_rain.unstack(1)
# Out:
#             outflow_octsep           outflow_decfeb           outflow_junaug  \
# rain_octsep           0         1000           0         1000           0
# year
# 1980             4,297.500 5,289.625      7,685.000 7,933.000      1,259.000
# 1990             3,479.000 5,064.889      5,515.000 8,363.111      1,439.000
# 2000                   nan 5,030.800            nan 7,812.100            nan
# 2010                   nan 5,116.667            nan 7,946.000            nan
#
#
# rain_octsep      1000
# year
# 1980        2,572.250
# 1990        2,130.556
# 2000        2,685.900
# 2010        3,314.333

# %%
# Creat a new dataframe containing entries which has rain_octsep values of greater than 1250
high_rain = df[df.rain_octsep > 1250]
high_rain
# Out:
#    water_year  rain_octsep  outflow_octsep  rain_decfeb  outflow_decfeb  \
# 18    1998/99         1268            5824          360            8771
# 26    2006/07         1387            6391          437           10926
# 31    2011/12         1285            5500          339            7630
#
#     rain_junaug  outflow_junaug  year
# 18          225            2240  1998
# 26          357            5168  2006
# 31          379            5261  2011

# %%
#Pivoting
#does set_index, sort_index and unstack in a row
high_rain.pivot('year', 'rain_octsep')[['outflow_octsep', 'outflow_decfeb', 'outflow_junaug']].fillna('')
# Out:
#             outflow_octsep                     outflow_decfeb            \
# rain_octsep           1268      1285      1387           1268      1285
# year
# 1998             5,824.000       nan       nan      8,771.000       nan
# 2006                   nan       nan 6,391.000            nan       nan
# 2011                   nan 5,500.000       nan            nan 7,630.000
#
#                        outflow_junaug
# rain_octsep       1387           1268      1285      1387
# year
# 1998               nan      2,240.000       nan       nan
# 2006        10,926.000            nan       nan 5,168.000
# 2011               nan            nan 5,261.000       nan

# %%
# Using pandas to quickly plot graphs
df.plot(x='year', y=['rain_octsep'])
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# Saving your data to a csv
df.to_csv('uk_rain.csv')
